# %%
import pandas as pd
import numpy as np
import random
import time
import math
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import pickle

# %%
df = pd.read_csv("mockdata.csv")
df['basePrice'] = df.apply(lambda row: float(row['basePrice'].strip()[1:]), axis=1)
df['quantity'] = np.random.randint(1,50,df.shape[0])
df['wastage'] = np.random.randint(0,50, df.shape[0])/100
df['dynamicPrice'] = df.apply(lambda row: row['basePrice'] - 0.6*row['basePrice']/(1+math.log(row['daysToExpiry'])), axis=1)
df
# Out:
#                                name  basePrice  daysToExpiry  quantity  \
# 0            Wild Boar - Tenderloin      20.88            11        35
# 1    Seedlings - Buckwheat, Organic      29.74            10        22
# 2              Bread - Bagels, Mini      26.20            12         4
# 3       Bread - Italian Sesame Poly      18.77            18        15
# 4                  Urban Zen Drinks       2.01            13        41
# ..                              ...        ...           ...       ...
# 995                 Sausage - Liver       3.04            11        36
# 996           Pie Filling - Pumpkin       1.18            29        25
# 997       Tequila Rose Cream Liquor       0.45            29        25
# 998                Cleaner - Bleach      15.83            13        41
# 999                 Prunes - Pitted      17.31            30        15
#
#      wastage  dynamicPrice
# 0       0.06     17.193012
# 1       0.35     24.336960
# 2       0.09     21.689119
# 3       0.41     15.875161
# 4       0.34      1.671706
# ..       ...           ...
# 995     0.13      2.503197
# 996     0.12      1.017886
# 997     0.37      0.388177
# 998     0.33     13.165727
# 999     0.48     14.950188
#
# [1000 rows x 6 columns]

# %%
model = RandomForestRegressor(random_state=1, n_estimators=10)

# %%
x = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values
model.fit(x[100:], y[100:])
pred = model.predict(x)

# %%
df['predictedPrice'] = pred
df
# Out:
#                                name  basePrice  daysToExpiry  quantity  \
# 0            Wild Boar - Tenderloin      20.88            11        35
# 1    Seedlings - Buckwheat, Organic      29.74            10        22
# 2              Bread - Bagels, Mini      26.20            12         4
# 3       Bread - Italian Sesame Poly      18.77            18        15
# 4                  Urban Zen Drinks       2.01            13        41
# ..                              ...        ...           ...       ...
# 995                 Sausage - Liver       3.04            11        36
# 996           Pie Filling - Pumpkin       1.18            29        25
# 997       Tequila Rose Cream Liquor       0.45            29        25
# 998                Cleaner - Bleach      15.83            13        41
# 999                 Prunes - Pitted      17.31            30        15
#
#      wastage  dynamicPrice  predictedPrice
# 0       0.06     17.193012       17.104719
# 1       0.35     24.336960       24.475238
# 2       0.09     21.689119       21.151313
# 3       0.41     15.875161       15.852812
# 4       0.34      1.671706        1.745466
# ..       ...           ...             ...
# 995     0.13      2.503197        2.519120
# 996     0.12      1.017886        1.005951
# 997     0.37      0.388177        0.398103
# 998     0.33     13.165727       13.130163
# 999     0.48     14.950188       14.878010
#
# [1000 rows x 7 columns]

# %%
filename = 'rf_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
filename = 'rf_model.sav'
model = pickle.load(open(filename, 'rb'))
